# %% [markdown]
# import thu vien

# %%
# %matplotlib inline
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from itertools import combinations 
from sklearn.cluster import KMeans
import folium
# Load data
data = pd.read_csv('dis.csv',
                   delimiter='\t',)

# %%
data.head()
# Out:
#      Location Name  Latitude  Longtitude        Volume Location Type
# 0        Hải Phòng   20.8000    106.6667  6.714954e+07        Supply
# 1  TP. Hồ Chí Minh   10.8167    106.6333  3.266500e+08        Supply
# 2           Hà Nội   21.0245    105.8412  2.387058e+08        Demand
# 3         Bắc Ninh   21.1861    106.0763  2.620998e+07        Demand
# 4        Vĩnh Phúc   21.3100    105.5967  2.642659e+07        Demand

# %%
# Color options
color_options = {'demand': 'red',
                 'supply': 'green',
                 'flow': 'black',
                 'cog': 'blue',
                 'candidate': 'black',
                 'other': 'gray'}
# Instantiate map
m = folium.Map(location=data[['Latitude', 'Longtitude']].mean(),
               fit_bounds=[[data['Latitude'].min(),
                            data['Longtitude'].min()], 
                           [data['Latitude'].max(),
                            data['Longtitude'].max()]])
                            
# Add volume points
for _, row in data.iterrows():
    folium.CircleMarker(location=[row['Latitude'], 
                                  row['Longtitude']],
                        radius=(row['Volume']**0.5*0.001),
                        weight=1,
                        color=color_options.get(str(row['Location Type']).lower(), 'gray'),
                        tooltip=str(row['Location Name'])+' '+str(row['Volume'])).add_to(m)
                                #row['Longtitude']]).add_to(m)
        
# Zoom based on volume points
m.fit_bounds(data[['Latitude', 'Longtitude']].values.tolist())
# Show the map
m
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/folium/utilities.py:86: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a217c434731f33b8f2d5d88095a556f7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a217c434731f33b8f2d5d88095a556f7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a217c434731f33b8f2d5d88095a556f7 = L.map(
#                 &quot;map_a217c434731f33b8f2d5d88095a556f7&quot;,
#                 {
#                     center: [13.958858333333332, 106.63358055555555],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     fitBounds: [[9.1833, 103.9572], [21.31, 109.2237]],
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5f1ee15a3f1ab6b5f6112ae8c2c8bffe = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5f1ee15a3f1ab6b5f6112ae8c2c8bffe.addTo(map_a217c434731f33b8f2d5d88095a556f7);
#
#
#             var circle_marker_14d446171eeccb9765ae6c7ca2da1df1 = L.circleMarker(
#                 [20.8, 106.6667],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8.194482487015271, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_a217c434731f33b8f2d5d88095a556f7);
#
#
#             circle_marker_14d446171eeccb9765ae6c7ca2da1df1.bindTooltip(
#                 `&lt;div&gt;
#                      Hải Phòng 67149543.23
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_9d73f4fe93a3c056d92e2dd4e8692a15 = L.circleMarker(
#                 [10.8167, 106.6333],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 18.073462205399384, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_a217c434731f33b8f2d5d88095a556f7);
#
#
#             circle_marker_9d73f4fe93a3c056d92e2dd4e8692a15.bindTooltip(
#                 `&lt;div&gt;
#                      TP. Hồ Chí Minh 326650036.09
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_f2602860fb10ce4875a47ce906c719bc = L.circleMarker(
#                 [21.0245, 105.8412],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 15.450106653353561, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_a217c434731f33b8f2d5d88095a556f7);
#
#
#             circle_marker_f2602860fb10ce4875a47ce906c719bc.bindTooltip(
#                 `&lt;div&gt;
#                      Hà Nội 238705795.6
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_9f4b162582bff43fdbe218c9e0959c88 = L.circleMarker(
#                 [21.1861, 106.0763],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5.11956863417222, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_a217c434731f33b8f2d5d88095a556f7);
#
#
#             circle_marker_9f4b162582bff43fdbe218c9e0959c88.bindTooltip(
#                 `&lt;div&gt;
#                      Bắc Ninh 26209983.0
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_3ab1d7595202c6ff55086374630bcb38 = L.circleMarker(
#                 [21.31, 105.5967],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2,

# %%
# The outbound shipments cost twice as much as inbound shipments
IB_OB_ratio = 1
def loc_type_mult(x):
    """A function to get the volume multiplier based on the location type and the IB-OB ratio.
    x: The location type
    """
    if x.lower() == 'supply':
        # No need to divide since we are already multiplying the demand
        return 1
    elif x.lower() == 'demand':
        # Only apply multiplier to demand
        return IB_OB_ratio
    else:
        # If neither supply nor demand, remove entirely
        return 0
# Adjust volumes used in the computation based on IB-OB ratio
data['Calc_Vol'] = data['Location Type'].apply(str).apply(loc_type_mult)*data['Volume']

# %%
data.head()
# Out:
#      Location Name  Latitude  Longtitude        Volume Location Type  \
# 0        Hải Phòng   20.8000    106.6667  6.714954e+07        Supply
# 1  TP. Hồ Chí Minh   10.8167    106.6333  3.266500e+08        Supply
# 2           Hà Nội   21.0245    105.8412  2.387058e+08        Demand
# 3         Bắc Ninh   21.1861    106.0763  2.620998e+07        Demand
# 4        Vĩnh Phúc   21.3100    105.5967  2.642659e+07        Demand
#
#        Calc_Vol
# 0  6.714954e+07
# 1  3.266500e+08
# 2  2.387058e+08
# 3  2.620998e+07
# 4  2.642659e+07

# %%
# Fit K-means for 2 centroids
kmeans = KMeans(n_clusters=2, 
                random_state=0).fit(data.loc[data['Calc_Vol']>0, ['Latitude', 
                                                                  'Longtitude']], 
                                    sample_weight=data.loc[data['Calc_Vol']>0, 
                                                           'Calc_Vol'])
# Get centers of gravity from K-means
cogs = kmeans.cluster_centers_
cogs = pd.DataFrame(cogs, columns=['Latitude',
                                   'Longtitude'])
# Get volume assigned to each cluster
data['Cluster'] = kmeans.predict(data[['Latitude', 'Longtitude']])
cogs = cogs.join(data.groupby('Cluster')['Volume'].sum())
# Include assigned COG coordinates in data by point 
data = data.join(cogs, on='Cluster', rsuffix='_COG')

# %%
data.head()
# Out:
#      Location Name  Latitude  Longtitude        Volume Location Type  \
# 0        Hải Phòng   20.8000    106.6667  6.714954e+07        Supply
# 1  TP. Hồ Chí Minh   10.8167    106.6333  3.266500e+08        Supply
# 2           Hà Nội   21.0245    105.8412  2.387058e+08        Demand
# 3         Bắc Ninh   21.1861    106.0763  2.620998e+07        Demand
# 4        Vĩnh Phúc   21.3100    105.5967  2.642659e+07        Demand
#
#        Calc_Vol  Cluster  Latitude_COG  Longtitude_COG    Volume_COG
# 0  6.714954e+07        1     20.722094      106.080005  5.289651e+08
# 1  3.266500e+08        0     11.189729      106.718901  1.135910e+09
# 2  2.387058e+08        1     20.722094      106.080005  5.289651e+08
# 3  2.620998e+07        1     20.722094      106.080005  5.289651e+08
# 4  2.642659e+07        1     20.722094      106.080005  5.289651e+08

# %%
# Add flow lines to centers of gravity to map
for _, row in data.iterrows():
    # Flow lines
    if str(row['Location Type']).lower() in (['demand', 'supply']):
        folium.PolyLine([(row['Latitude'],
                          row['Longtitude']),
                         (row['Latitude_COG'],
                          row['Longtitude_COG'])],
                        color=color_options['flow'],
                        weight=(row['Volume']**0.5*0.0001),
                        opacity=0.8).add_to(m)
                        
# Add centers of gravity to map
for _, row in cogs.iterrows():
    # New centers of gravity
    folium.CircleMarker(location=[row['Latitude'],
                                  row['Longtitude']],
                        radius=(row['Volume']**0.5**0.001),
                        color=color_options['cog'],
                        tooltip=row['Volume']).add_to(m)
    
# Show map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a217c434731f33b8f2d5d88095a556f7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a217c434731f33b8f2d5d88095a556f7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a217c434731f33b8f2d5d88095a556f7 = L.map(
#                 &quot;map_a217c434731f33b8f2d5d88095a556f7&quot;,
#                 {
#                     center: [13.958858333333332, 106.63358055555555],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     fitBounds: [[9.1833, 103.9572], [21.31, 109.2237]],
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5f1ee15a3f1ab6b5f6112ae8c2c8bffe = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5f1ee15a3f1ab6b5f6112ae8c2c8bffe.addTo(map_a217c434731f33b8f2d5d88095a556f7);
#
#
#             var circle_marker_14d446171eeccb9765ae6c7ca2da1df1 = L.circleMarker(
#                 [20.8, 106.6667],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8.194482487015271, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_a217c434731f33b8f2d5d88095a556f7);
#
#
#             circle_marker_14d446171eeccb9765ae6c7ca2da1df1.bindTooltip(
#                 `&lt;div&gt;
#                      Hải Phòng 67149543.23
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_9d73f4fe93a3c056d92e2dd4e8692a15 = L.circleMarker(
#                 [10.8167, 106.6333],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 18.073462205399384, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_a217c434731f33b8f2d5d88095a556f7);
#
#
#             circle_marker_9d73f4fe93a3c056d92e2dd4e8692a15.bindTooltip(
#                 `&lt;div&gt;
#                      TP. Hồ Chí Minh 326650036.09
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_f2602860fb10ce4875a47ce906c719bc = L.circleMarker(
#                 [21.0245, 105.8412],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 15.450106653353561, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_a217c434731f33b8f2d5d88095a556f7);
#
#
#             circle_marker_f2602860fb10ce4875a47ce906c719bc.bindTooltip(
#                 `&lt;div&gt;
#                      Hà Nội 238705795.6
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_9f4b162582bff43fdbe218c9e0959c88 = L.circleMarker(
#                 [21.1861, 106.0763],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5.11956863417222, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_a217c434731f33b8f2d5d88095a556f7);
#
#
#             circle_marker_9f4b162582bff43fdbe218c9e0959c88.bindTooltip(
#                 `&lt;div&gt;
#                      Bắc Ninh 26209983.0
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_3ab1d7595202c6ff55086374630bcb38 = L.circleMarker(
#                 [21.31, 105.5967],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2,

# %%
cogs
# Out:
#     Latitude  Longtitude        Volume
# 0  11.189729  106.718901  1.135910e+09
# 1  20.722094  106.080005  5.289651e+08

# %% [markdown]
# # Itertools

# %%
# %matplotlib inline
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from itertools import combinations 
from tqdm import tqdm
from sklearn.cluster import KMeans
import folium

data = pd.read_csv('dis.csv',
                   delimiter='\t',)
                             
# Color options
color_options = {'demand': 'red',
                 'supply': 'yellow',
                 'flow': 'black',
                 'cog': 'blue',
                 'candidate': 'black',
                 'other': 'gray'}
# Instantiate map
m = folium.Map(location=data[['Latitude', 'Longtitude']].mean(),
               fit_bounds=[[data['Latitude'].min(),
                            data['Longtitude'].min()], 
                           [data['Latitude'].max(),
                            data['Longtitude'].max()]])
                            
# Add volume points
for _, row in data.iterrows():
    folium.CircleMarker(location=[row['Latitude'], 
                                  row['Longtitude']],
                        radius=(row['Volume']**0.5*0.001),
                        weight=1,
                        color=color_options.get(str(row['Location Type']).lower(), 'gray'),
                        tooltip=str(row['Location Name'])+' '+str(row['Volume'])).add_to(m)
                                #row['Longtitude']]).add_to(m)
        
# Zoom based on volume points
m.fit_bounds(data[['Latitude', 'Longtitude']].values.tolist())
# Show the map
m
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/folium/utilities.py:86: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_757a1b63a5439f73a8428e25cb18511b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_757a1b63a5439f73a8428e25cb18511b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_757a1b63a5439f73a8428e25cb18511b = L.map(
#                 &quot;map_757a1b63a5439f73a8428e25cb18511b&quot;,
#                 {
#                     center: [13.958858333333332, 106.63358055555555],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     fitBounds: [[9.1833, 103.9572], [21.31, 109.2237]],
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9dd2ffc1442616e837eca594f837f491 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9dd2ffc1442616e837eca594f837f491.addTo(map_757a1b63a5439f73a8428e25cb18511b);
#
#
#             var circle_marker_b39b38478c4c6da64abb8461692b6fd1 = L.circleMarker(
#                 [20.8, 106.6667],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8.194482487015271, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_757a1b63a5439f73a8428e25cb18511b);
#
#
#             circle_marker_b39b38478c4c6da64abb8461692b6fd1.bindTooltip(
#                 `&lt;div&gt;
#                      Hải Phòng 67149543.23
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_e584a48d38acf7b1e73d872cc43e4a28 = L.circleMarker(
#                 [10.8167, 106.6333],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 18.073462205399384, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_757a1b63a5439f73a8428e25cb18511b);
#
#
#             circle_marker_e584a48d38acf7b1e73d872cc43e4a28.bindTooltip(
#                 `&lt;div&gt;
#                      TP. Hồ Chí Minh 326650036.09
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_e97b1410174bdfe5218e2540597ed136 = L.circleMarker(
#                 [21.0245, 105.8412],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 15.450106653353561, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_757a1b63a5439f73a8428e25cb18511b);
#
#
#             circle_marker_e97b1410174bdfe5218e2540597ed136.bindTooltip(
#                 `&lt;div&gt;
#                      Hà Nội 238705795.6
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_a01bd6144aa69f7f39af42fb2110a1d6 = L.circleMarker(
#                 [21.1861, 106.0763],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5.11956863417222, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_757a1b63a5439f73a8428e25cb18511b);
#
#
#             circle_marker_a01bd6144aa69f7f39af42fb2110a1d6.bindTooltip(
#                 `&lt;div&gt;
#                      Bắc Ninh 26209983.0
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_49c87a0cfe574a9d4211f1394fb3fdfe = L.circleMarker(
#                 [21.31, 105.5967],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0

# %%
# The outbound shipments cost twice as much as inbound shipments
IB_OB_ratio = 2
def loc_type_mult(x):
    """A function to get the volume multiplier based on the location type and the IB-OB ratio.
    x: The location type
    """
    if x.lower() == 'supply':
        # No need to divide since we are already multiplying the demand
        return 1
    elif x.lower() == 'demand':
        # Only apply multiplier to demand
        return IB_OB_ratio
    else:
        # If neither supply nor demand, remove entirely
        return 0
# Adjust volumes used in the computation based on IB-OB ratio
data['Calc_Vol'] = data['Location Type'].apply(str).apply(loc_type_mult)*data['Volume']

# %%
data.head()
# Out:
#      Location Name  Latitude  Longtitude        Volume Location Type  \
# 0        Hải Phòng   20.8000    106.6667  6.714954e+07        Supply
# 1  TP. Hồ Chí Minh   10.8167    106.6333  3.266500e+08        Supply
# 2           Hà Nội   21.0245    105.8412  2.387058e+08        Demand
# 3         Bắc Ninh   21.1861    106.0763  2.620998e+07        Demand
# 4        Vĩnh Phúc   21.3100    105.5967  2.642659e+07        Demand
#
#        Calc_Vol
# 0  6.714954e+07
# 1  3.266500e+08
# 2  4.774116e+08
# 3  5.241997e+07
# 4  5.285319e+07

# %%
n = 2 # Number of warehouse
cands = data.loc[data['Location Type'].str.lower()=='candidate']
locs = data.loc[data['Calc_Vol']>0]
total_dist = np.inf
best_cogs = []
# Loop to find best combination of candidate sites
for i in tqdm(list(combinations(cands.index, n))):
    temp_cands = cands.loc[list(i)]
    locs['Cluster'] = 0
    locs['Distance_COG'] = np.inf
    for i_l, r_l in locs.iterrows():
        for i_c, r_c in temp_cands.iterrows():
            # Get distance
            dist = (r_l['Latitude']-r_c['Latitude'])**2
            dist += (r_l['Longtitude']-r_c['Longtitude'])**2
            dist **= 0.5
            # Save values if distance is shorter
            if dist < locs.loc[i_l, 'Distance_COG']:
                # Save distance
                locs.loc[i_l, 'Distance_COG'] = dist
                # Save index of nearest point
                locs.loc[i_l, 'Cluster'] = i_c
    # Weight distance by volume
    locs['Weighted_Distance_COG'] = locs['Distance_COG'] * locs['Calc_Vol']
    # Save scenario if total weighted distance is smaller
    if locs['Weighted_Distance_COG'].sum() < total_dist:
        total_dist = locs['Weighted_Distance_COG'].sum()
        best_cogs = list(list(i))
# Get centers of gravity
cogs = cands.loc[best_cogs, ['Latitude',
                             'Longtitude']]
# Reloop to get site assignment
locs['Cluster'] = 0
locs['Distance_COG'] = np.inf
for i_l, r_l in locs.iterrows():
    for i_c, r_c in cogs.iterrows():
        # Get distance
        dist = (r_l['Latitude']-r_c['Latitude'])**2
        dist += (r_l['Longtitude']-r_c['Longtitude'])**2
        dist **= 0.5
        # Save values if distance is shorter
        if dist < locs.loc[i_l, 'Distance_COG']:
            # Save distance
            locs.loc[i_l, 'Distance_COG'] = dist
            # Save index of nearest point
            locs.loc[i_l, 'Cluster'] = i_c
# Get volume assigned to each cog
cogs = cogs.join(locs.groupby('Cluster')['Volume'].sum())
# Include assigned COG coordinates in data by point 
data = data.join(locs['Cluster'])
data = data.join(cogs, on='Cluster', rsuffix='_COG')
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]/var/folders/ck/qv1xpztn37jcd09zt1c4dgy40000gn/T/ipykernel_18583/3634644166.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   locs['Cluster'] = 0
# /var/folders/ck/qv1xpztn37jcd09zt1c4dgy40000gn/T/ipykernel_18583/3634644166.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   locs['Distance_COG'] = np.inf
# /var/folders/ck/qv1xpztn37jcd09zt1c4dgy40000gn/T/ipykernel_18583/3634644166.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   locs['Weighted_Distance_COG'] = locs['Distance_COG'] * locs['Calc_Vol']
# /var/folders/ck/qv1xpztn37jcd09zt1c4dgy40000gn/T/ipykernel_18583/3634644166.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   locs['Cluster'] = 0
# /var/folders/ck/qv1xpztn37jcd09zt1c4dgy40000gn/T/ipykernel_18583/3634644166.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   locs['Distance_COG'] = np.inf
# /var/folders/ck/qv1xpztn37jcd09zt1c4dgy40000gn/T/ipykernel_18583/3634644166.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   locs['Weighted_Distance_COG'] = locs['Distance_COG'] * locs['Calc_Vol']
# /var/folders/ck/qv1xpztn37jcd09zt1c4dgy40000gn/T/ipykernel_18583/3634644166.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   locs['Cluster'] = 0
# /var/folders/ck/qv1xpztn37jcd09zt1c4dgy40000gn/T/ipykernel_18583/3634644166.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   locs['Distance_COG'] = np.inf
# /var/folders/ck/qv1xpztn37jcd09zt1c4dgy40000gn/T/ipykernel_18583/3634644166.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   locs['Weighted_Distance_COG'] = locs['Distance_COG'] * locs['Calc_Vol']
# /var/folders/ck/qv1xpztn37jcd09zt1c4dgy40000gn/T/ipykernel_18583/3634644166.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   locs['Cluster'] = 0
# /var/folders/ck/qv1xpztn37jcd09zt1c4dgy40000gn/T/ipykernel_18583/3634644166.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   locs['Distance_COG'] = np.inf
# /var/folders/ck/qv1xpztn37jcd09zt1c4dgy40000gn/T/ipykernel_18583/3634644166.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   locs['Weighted_Distance_COG'] = locs['Distance_COG'] * locs['Calc_Vol']
# /var/folders/ck/qv1xpztn37jcd09zt1c4dgy40000gn/T/ipykernel_18583/3634644166.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   locs['Cluster'] = 0
# /var/folders/ck/qv1xpztn37jcd09zt1c4dgy40000gn/T/ipykernel_18583/3634644166.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   locs['Distance_COG'] = np.inf
# /var/folders/ck/qv1xpztn37jcd09zt1c4dgy40000gn/T/ipykernel_18583/3634644166.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   locs['Weighted_Distance_COG'] = locs['Distance_COG'] * locs['Calc_Vol']
# /var/folders/ck/qv1xpztn37jcd09zt1c4dgy40000gn/T/ipykernel_18583/3634644166.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   locs['Cluster'] = 0
# /var/folders/ck/qv1xpztn37jcd09zt1c4dgy40000gn/T/ipykernel_18583/3634644166.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   locs['Distance_COG'] = np.inf
# /var/folders/ck/qv1xpztn37jcd09zt1c4dgy40000gn/T/ipykernel_18583/3634644166.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   locs['Weighted_Distance_COG'] = locs['Distance_COG'] * locs['Calc_Vol']
# /var/folders/ck/qv1xpztn37jcd09zt1c4dgy40000gn/T/ipykernel_18583/3634644166.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   locs['Cluster'] = 0
# /var/folders/ck/qv1xpztn37jcd09zt1c4dgy40000gn/T/ipykernel_18583/3634644166.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   locs['Distance_COG'] = np.inf
# /var/folders/ck/qv1xpztn37jcd09zt1c4dgy40000gn/T/ipykernel_18583/3634644166.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   locs['Weighted_Distance_COG'] = locs['Distance_COG'] * locs['Calc_Vol']
# /var/folders/ck/qv1xpztn37jcd09zt1c4dgy40000gn/T/ipykernel_18583/3634644166.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   locs['Cluster'] = 0
# /var/folders/ck/qv1xpztn37jcd09zt1c4dgy40000gn/T/ipykernel_18583/3634644166.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   locs['Distance_COG'] = np.inf
# /var/folders/ck/qv1xpztn37jcd09zt1c4dgy40000gn/T/ipykernel_18583/3634644166.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   locs['Weighted_Distance_COG'] = locs['Distance_COG'] * locs['Calc_Vol']
# /var/folders/ck/qv1xpztn37jcd09zt1c4dgy40000gn/T/ipykernel_18583/3634644166.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   locs['Cluster'] = 0
# /var/folders/ck/qv1xpztn37jcd09zt1c4dgy40000gn/T/ipykernel_18583/3634644166.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   locs['Distance_COG'] = np.inf
# /var/folders/ck/qv1xpztn37jcd09zt1c4dgy40000gn/T/ipykernel_18583/3634644166.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   locs['Weighted_Distance_COG'] = locs['Distance_COG'] * locs['Calc_Vol']
#  90%|█████████ | 9/10 [00:00<00:00, 84.76it/s]/var/folders/ck/qv1xpztn37jcd09zt1c4dgy40000gn/T/ipykernel_18583/3634644166.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   locs['Cluster'] = 0
# /var/folders/ck/qv1xpztn37jcd09zt1c4dgy40000gn/T/ipykernel_18583/3634644166.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   locs['Distance_COG'] = np.inf
# /var/folders/ck/qv1xpztn37jcd09zt1c4dgy40000gn/T/ipykernel_18583/3634644166.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   locs['Weighted_Distance_COG'] = locs['Distance_COG'] * locs['Calc_Vol']
# 100%|██████████| 10/10 [00:00<00:00, 86.16it/s]
# /var/folders/ck/qv1xpztn37jcd09zt1c4dgy40000gn/T/ipykernel_18583/3634644166.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   locs['Cluster'] = 0
# /var/folders/ck/qv1xpztn37jcd09zt1c4dgy40000gn/T/ipykernel_18583/3634644166.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   locs['Distance_COG'] = np.inf

# %%
# Add flow lines to centers of gravity to map
for _, row in data.iterrows():
    # Flow lines
    if str(row['Location Type']).lower() in (['demand', 'supply']):
        folium.PolyLine([(row['Latitude'],
                          row['Longtitude']),
                         (row['Latitude_COG'],
                          row['Longtitude_COG'])],
                        color=color_options['flow'],
                        weight=(row['Volume']**0.5*0.0001),
                        opacity=0.8).add_to(m)
                        
# Add centers of gravity to map
for _, row in cogs.iterrows():
    # New centers of gravity
    folium.CircleMarker(location=[row['Latitude'],
                                  row['Longtitude']],
                        radius=(row['Volume']**0.5*0.001),
                        weight=1.5,
                        color=color_options['cog'],
                        tooltip=row['Volume']).add_to(m)
    
# Show map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_757a1b63a5439f73a8428e25cb18511b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_757a1b63a5439f73a8428e25cb18511b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_757a1b63a5439f73a8428e25cb18511b = L.map(
#                 &quot;map_757a1b63a5439f73a8428e25cb18511b&quot;,
#                 {
#                     center: [13.958858333333332, 106.63358055555555],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     fitBounds: [[9.1833, 103.9572], [21.31, 109.2237]],
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9dd2ffc1442616e837eca594f837f491 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9dd2ffc1442616e837eca594f837f491.addTo(map_757a1b63a5439f73a8428e25cb18511b);
#
#
#             var circle_marker_b39b38478c4c6da64abb8461692b6fd1 = L.circleMarker(
#                 [20.8, 106.6667],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8.194482487015271, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_757a1b63a5439f73a8428e25cb18511b);
#
#
#             circle_marker_b39b38478c4c6da64abb8461692b6fd1.bindTooltip(
#                 `&lt;div&gt;
#                      Hải Phòng 67149543.23
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_e584a48d38acf7b1e73d872cc43e4a28 = L.circleMarker(
#                 [10.8167, 106.6333],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 18.073462205399384, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_757a1b63a5439f73a8428e25cb18511b);
#
#
#             circle_marker_e584a48d38acf7b1e73d872cc43e4a28.bindTooltip(
#                 `&lt;div&gt;
#                      TP. Hồ Chí Minh 326650036.09
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_e97b1410174bdfe5218e2540597ed136 = L.circleMarker(
#                 [21.0245, 105.8412],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 15.450106653353561, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_757a1b63a5439f73a8428e25cb18511b);
#
#
#             circle_marker_e97b1410174bdfe5218e2540597ed136.bindTooltip(
#                 `&lt;div&gt;
#                      Hà Nội 238705795.6
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_a01bd6144aa69f7f39af42fb2110a1d6 = L.circleMarker(
#                 [21.1861, 106.0763],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5.11956863417222, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_757a1b63a5439f73a8428e25cb18511b);
#
#
#             circle_marker_a01bd6144aa69f7f39af42fb2110a1d6.bindTooltip(
#                 `&lt;div&gt;
#                      Bắc Ninh 26209983.0
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_49c87a0cfe574a9d4211f1394fb3fdfe = L.circleMarker(
#                 [21.31, 105.5967],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0
